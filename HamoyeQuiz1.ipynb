# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv"

# %%
url2= 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'

# %%
df = pd.read_csv(url, encoding='latin-1')
print(df.head(2))
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
df[['Y2017','Area']].groupby('Area').sum().sort_values('Y2017')
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %% [markdown]
# S = [['him', 'sell'], [90, 28, 43]]
#
# S[0][1][1]

# %%
df[['Y2014','Y2015','Y2016','Y2017','Y2018','Area','Element']].groupby('Element').sum()
# Out:
# <ipython-input-27-df0e06915a14>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Y2014','Y2015','Y2016','Y2017','Y2018','Area','Element']].groupby('Element').sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# ...

# %%
#Q6
df['Y2017'].std()
# Out:
# 1671.8623590567995

# %%
df['Y2017'].mean()
# Out:
# 140.9177648602722

# %%
df[['Y2015','Area','Element']].groupby('Element').sum()
# Out:
# <ipython-input-36-18b3f9ef4768>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Y2015','Area','Element']].groupby('Element').sum()
#                                              Y2015
# Element
# Domestic supply quantity                2021493.55
# Export Quantity                          157614.47
# Fat supply quantity (g/capita/day)        10235.74
# Feed                                     225050.22
# Food                                    1232361.10
# Food supply (kcal/capita/day)            453383.00
# Food supply quantity (kg/capita/yr)       49345.13
# Import Quantity                          267018.46
# Losses                                   155439.00
# Other uses (non-food)                     66254.41
# Processing                               287929.00
# ...

# %%
df[['Y2017','Area','Element']].groupby('Element').sum()
# Out:
# <ipython-input-54-3c61e0dff20d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Y2017','Area','Element']].groupby('Element').sum()
#                                              Y2017
# Element
# Domestic supply quantity                2088198.10
# Export Quantity                          182338.80
# Fat supply quantity (g/capita/day)        10253.84
# Feed                                     223705.68
# Food                                    1258888.28
# Food supply (kcal/capita/day)            454681.00
# Food supply quantity (kg/capita/yr)       48690.04
# Import Quantity                          294559.09
# Losses                                   160614.00
# Other uses (non-food)                     91645.97
# Processing                               292836.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
#Q11
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(df.groupby('Area').sum())
# Out:
# <ipython-input-46-58ec69a282f9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   len(df.groupby('Area').sum())
# 49

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
df[['Y2015','Item']].groupby('Item').sum()
# Out:
#                          Y2015
# Item
# Alcohol, Non-Food      2180.00
# Alcoholic Beverages   98783.72
# Animal Products       11811.73
# Animal fats          200675.72
# Apples and products   10559.15
# ...                        ...
# Vegetables, Other    158104.08
# Vegetal Products     107064.17
# Wheat and products   234710.51
# Wine                   4251.81
# Yams                 203151.78
#
# [119 rows x 1 columns]

# %%
#Q8
df[['Y2017','Area']].groupby('Area').sum().sort_values('Y2017')
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
df[['Y2015','Area','Element']].groupby('Element')('Madagascar').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-6e656454a189> in <cell line: 1>()
# ----> 1 df[['Y2015','Area','Element']].groupby('Element')('Madagascar').sum()
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
#Q13
df[['Y2015','Area','Element']].groupby('Area').sum()
# Out:
# <ipython-input-72-e9f4a28a4b20>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Y2015','Area','Element']].groupby('Area').sum()
#                                   Y2015
# Area
# Algeria                       324058.40
# Angola                        209565.67
# Benin                         108181.13
# Botswana                       23024.85
# Burkina Faso                  102701.22
# Cabo Verde                     14538.93
# Cameroon                      225220.72
# Central African Republic       28885.34
# Chad                           65835.88
# Comoros                           41.34
# Congo                          40255.51
# Côte d'Ivoire                 211591.29
# Djibouti                       23690.16
# Egypt                         868218.73
# ...

# %%
Mad = df[df['Area']=='Madagascar']

# %%
#Q7
Mad.groupby('Element').sum()
# Out:
# <ipython-input-78-09c9550afebd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Mad.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    15351     318888        630819
# Export Quantity                             13416     279445        614744
# Fat supply quantity (g/capita/day)          14319     299405         75924
# Feed                                         4515      94030        193235
# Food                                        14190     295817        565620
# Food supply (kcal/capita/day)               14319     299405         73704
# Food supply quantity (kg/capita/yr)         14190     295817         70950
# ...

# %%
df.groupby('Element').std()
# Out:
# <ipython-input-81-3412d5ceb282>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element').std()
#                                         Area Code   Item Code  Element Code  \
# Element
# Domestic supply quantity                72.429582  141.576118           0.0
# Export Quantity                         72.474261  143.600685           0.0
# Fat supply quantity (g/capita/day)      72.408886  145.158765           0.0
# Feed                                    71.452934  175.302998           0.0
# Food                                    72.466059  141.888290           0.0
# Food supply (kcal/capita/day)           72.358700  145.091463           0.0
# Food supply quantity (kg/capita/yr)     72.455564  142.245258           0.0
# ...

# %%
#q11
df.groupby('Element Code').std().min()
# Out:
# <ipython-input-85-73833b8a310a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element Code').std().min()
# Area Code    59.925421
# Item Code     0.000000
# Y2014         4.108235
# Y2015         3.348996
# Y2016         0.601934
# Y2017         0.624528
# Y2018         0.617736
# dtype: float64
